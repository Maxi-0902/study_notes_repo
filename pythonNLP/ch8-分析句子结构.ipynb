# %% [markdown]
# ## 第8章 分析句子结构
#
# 前面的章节重点关注词：如何识别它们，分析它们的结构，分配给他们词汇类别，以及获得它们的含义。我们还看到了如何识别词序列或 `n-grams` 的模式。然而，这些方法只触碰到管理句子的复杂约束的表面。我们需要一种方法处理自然语言中显著的歧义。我们还需要能够应对这样一个事实：句子有无限的可能，而我们只能写有限的程序来分析其结构和发现它们的含义。
#
# 本章的目的是要回答下列问题：
# 1. 我们如何使用形式化语法来描述无限的句子集合的结构？
# 2. 我们如何使用句法树来表示句子结构？
# 3. 语法分析器如何分析一个句子并自动构建语法树？
#
# 一路上，我们将覆盖英语语法的基础，并看到句子含义有系统化的一面，只要我们确定了句子结构，将更容易捕捉。
#
# ### 8.1 一些语法困境
# #### 语言数据和无限可能性
#
# 文法的目的是给出一个明确的语言描述。
#
# 在这一章中，我们将采取“生成文法”的形式化框架，其中一种“语言”被认为是所有 合乎文法的句子的巨大集合，一个文法是一个形式化符号，可用于“产生“这个集合的成员。 文法使用`S → S and S` 形式的递归产生式，我们将在 8.3节探讨。第 10章中，我们会将其扩展到从它的组成部分的意思自动建立一个句子的意思。
#
# #### 普遍存在的歧义
#
# 让我们仔细看看短语 `I shot an elephant in my pajamas` 中的歧义。首先，我们需要定义一个简单的文法：

# %%
import nltk
groucho_grammar = nltk.CFG.fromstring("""
    S -> NP VP
    PP -> P NP
    NP -> Det N | Det N PP | 'I'
    VP -> V NP | VP PP
    Det -> 'an' | 'my'
    N -> 'elephant' | 'pajamas'
    V -> 'shot'
    P -> 'in'
""")

# %%
# 这个文法允许以两种方式分析句子，取决于介词短语 in my pajamas 是描述大象还是枪击事件。
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
trees = parser.parse(sent)
for tree in trees:
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %% [markdown]
# 本章介绍文法和分析，以形式化可计算的方法调查和建模我们一直在讨论的语言现象。 正如我们所看到的，词序列中符合语法规则的和不符合语法规则的模式相对于短语结构和依赖是可以被理解的。我们可以开发使用文法和分析的这些结构的形式化模型。与以前一样，一个重要的动机是自然语言理解。当我们能可靠地识别一个文本所包含的语言结构时，我们从中可以获得多少文本的含义？一个程序通读了一个文本，它能否足够“理解”它，来回答一些简单的关于“发生了什么事”或“谁对谁做了什么”的问题？还像以前一样，我们将开发简单的程序来处理已注释的语料库，并执行有用的任务。
#
# ### 8.2 文法有什么用？
# #### 超越`n-grams`
#
# 并列结构：如果`v1`和`v2`都是文法类型`X`的短语，那么 `v1 and v2` 也是`X` 类型的短语。
#
# 成分结构基于对词与其他词结合在一起形成单元的观察。一个词序列形成这样一个单元的证据是它是可替代的——也就是说，在一个符合语法规则的句子中的词序列可以被一个更小的序列替代而不会导致句子不符合语法规则。
#
# ### 8.3 上下文无关文法
# #### 一种简单的文法
#
# 首先，让我们看一个简单的上下文无关文法（`context-free grammar，CFG`）。按照惯例， 第一条生产式的左端是文法的开始符号，通常是 `S`，所有符合语法规则的树都必须有这个符号作为它们的根标签。NLTK 中，上下文无关文法定义在`nltk.grammar` 模块。在例 8-1 中，我们定义了文法，并显示如何分析一个简单的符合文法的句子。

# %%
# 例8-1. 上下文无关文法的例子。
grammar1 = nltk.CFG.fromstring("""
    S -> NP VP
    VP -> V NP | V NP PP
    PP -> P NP
    V -> "saw" | "ate" | "walked"
    NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
    Det -> "a" | "an" | "the" | "my"
    N -> "man" | "dog" | "cat" | "telescope" | "park"
    P -> "in" | "on" | "by" | "with"
""")

sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
    print(tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %% [markdown]
# 例 8-1 中的文法包含涉及各种句法类型的产生式，如表 8-1 中所列出的。在这里使用**递归下降分析器**也可以通过图形界面查看，如图 8-3 所示；我们在 8.4节中将更详细讨论这个分析器。
# ![8-3](./imgs/8-3.jpg)
#
# ![list8-1](./imgs/list8-1.jpg)
#
# 产生式如`VP -> V NP | V NP PP` 右侧脱节了，中间显示`|`，这是两个产生式 `VP -> V NP` 和 `VP -> V NP PP` 的缩写。
#
# 如果我们使用例 8-1 显示的文法分析句子`The dog saw a man in the park`，我们会得到两棵树，类似与我们在(3)中看到的：
# ![cfg](./imgs/cfg.jpg)
#
# 由**于这句话的两棵树都符合我们的文法规则，这句话被称为结构上有歧义**。这个歧义问题被称为**介词短语附着歧义**，正如我们在本章前面看到的。正如你可能还记得，这是一个附着歧义，因为 `PP in the park`需要附着在树中两个位置中的一个：要么是`VP` 的孩子要么是 `NP`的孩子。当 `PP`附着在`VP` 上，合适的解释是：看到公园里发生的事情。然而，如果`PP` 附着在`NP` 上，意思就是：在公园里的一个人，看到（狗）的主语可能已经坐在公寓的阳台上俯瞰公园。
#
# #### 写你自己的文法
#
# 如果你有兴趣尝试写上下文无关文法`CFG`，你会发现在一个文本文件`mygrammar.cfg`中创建和编辑你的语法会很有帮助。然后，你可以加载它到NLTK 中，并按如下方式用它进行分析：

# %%
grammar1 = nltk.data.load('file:mygrammar.cfg')
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
    print(tree)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-7-c9cb56046563> in <module>
# ----> 1 grammar1 = nltk.data.load('file:mygrammar.cfg')
#       2 sent = "Mary saw Bob".split()
#       3 rd_parser = nltk.RecursiveDescentParser(grammar1)
#       4 for tree in rd_parser.parse(sent):
#       5     print(tree)
#
# f:\Anaconda3\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# f:\Anaconda3\lib\site-packages\nltk\data.py in _open(resource_url)
#     994     elif protocol.lower() == 'file':
#     995         # urllib might not use mode='rb', so handle this one ourselves:
# --> 996         return find(path_, ['']).open()
#     997     else:
#     998         return urlopen(resource_url)
#
# f:\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource e: not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('e:')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load /e:/codes/vscode_home/pythonNLP/mygrammar.cfg
#
#   Searched in:
#     - ''
# **********************************************************************

# %% [markdown]
# 确保你的文件名后缀为`.cfg`，并且字符串`'file:mygrammar.cfg'`中间没有空格符。如果
# 命令`print tree` 没有产生任何输出，这可能是因为你的句子`sent` 并不符号你的文法。遇到这种情况可以将分析器的跟踪设置打开`rd_parser = nltk.RecursiveDescentParser(grammar1, trace=2)`。你还可以查看当前使用的文法中的产生式，使用命令 `for p in grammar1.productions(): print p`。 当你写`CFG` 在 NLTK中分析时，你不能将文法类型与词汇项目一起写在同一个产生式的右侧。因此，产生式`PP -> 'of' NP` 是不允许的。另外，你不得在产生式右侧仿制多个词的词汇项。因此，不能写成 `NP -> 'New York'`，而要写成类似` NP -> 'New_York'`这样的。
#
# #### 句法结构中的递归
#
# **一个文法被认为是递归的，如果文法类型出现在产生式左侧也出现在右侧**，如例 8-2所
# 示。产生式`Nom -> Adj Nom`（其中`Nom`是名词性的类别）包含 `Nom`类型的直接递归， 而`S` 上的间接递归来自于两个产生式的组合：`S -> NP VP` 与`VP -> V S`。

# %%
# 例8-2. 递归的上下文无关文法。
grammar2 = nltk.CFG.fromstring("""
    S -> NP VP
    NP -> Det Nom | PropN
    Nom -> Adj Nom | N
    VP -> V Adj | V NP | V S | V NP PP
    PP -> P NP
    PropN -> 'Buster' | 'Chatterer' | 'Joe'
    Det -> 'the' | 'a'
    N -> 'bear' | 'squirrel' | 'tree' | 'fish' | 'log'
    Adj -> 'angry' | 'frightened' | 'little' | 'tall'
    V -> 'chased' | 'saw' | 'said' | 'thought' | 'was' | 'put'
    P -> 'on'
""")

# %% [markdown]
# 要看递归如何从这个语法产生，思考下面的树。（10a）包括嵌套的名词短语，而（10b） 包含嵌套的句子。
# ![10a](./imgs/10a.jpg)
#
# ![10b](./imgs/10b.jpg)
#
# 我们在这里只演示了两个层次的递归，递归深度是没有限制的。你可以尝试分析更深层次嵌套结构的句子。请注意，`RecursiveDescentParser`是无法处理形如 `X -> X Y`的左递归产生式；我们将在第8.4节谈及这个。
#
# ### 8.4 上下文无关文法分析
#
# **分析器**根据文法产生式处理输入的句子，并建立一个或多个符合文法的组成结构。**文法是一个格式良好的声明规范——它实际上只是一个字符串**，而不是程序。**分析器是文法的解释程序**。它搜索符合文法的所有树的空间找出一棵边缘有所需句子的树。分析器允许使用一组测试句子评估一个文法，帮助语言学家发现在他们的文法分析中存在的错误。分析器可以作为心理语言处理模型，帮助解释人类处理某些句法结构的困难。许多自然语言应用程序都在某种程度涉及文法分析；例如：我们会期望自然语言问答系统对提交的问题首先进行文法分析。
#
# 在本节中，我们将看到两个简单的分析算法，**一种自上而下的方法称为递归下降分析**， **一种自下而上的方法称为移进-归约分析**。我们也将看到一些更复杂的算法，一种带自下而上过滤的自上而下的方法称为左角落分析；一种动态规划技术称为图表分析。
#
# #### 递归下降分析
#
# 一种最简单的分析器将一个文法作为如何将一个高层次的目标分解成几个低层次的子目标的规范来解释。顶层的目标是找到一个`S`。`S→NP VP` 生产式允许分析器替换这个目标为两个子目标：找到一个`NP`，然后找到一个 `VP`。每个这些子目标都可以再次被子目标的子目标替代，使用左侧有`NP` 和`VP` 的产生式。最终，这种扩张过程达到子目标，如：找到词 `telescope`。这样的子目标可以直接与输入序列比较，如果下一个单词匹配就取得成功。如果没有匹配，分析器必须备份，并尝试其它选择。
#
# 递归下降分析器在上述过程中建立分析树。带着最初的目标（找到一个`S`），创建 `S`根节点。随着上述过程使用文法的产生式递归扩展，分析树不断向下延伸（故名为递归下降）。我们可以在图形化示范`nltk.app.rdparser()`中看到这个过程。执行此分析器的六个阶段， 如图 8-4 所示。
# ![8-4](./imgs/8-4.jpg)
#
# 在这个过程中，分析器往往被迫在多种可能的产生式中选择。例如：从第3步到第4步，它试图找到左侧有`N` 的产生式。第一个是`N → man`。当这不起作用时就回溯，按顺序尝试其他左侧有`N` 的产生式，直到它得到 `N → dog`，与输入句子中的下一个词相匹配。一段时间以后，如第5 步所示，它发现了一个完整的分析树。这是一个涵盖了整个句子的树，没有任何悬着的边。发现了分析树后我们可以让分析器寻找其它额外的分析树。它会再次回溯和探索选择其它产生式，以免漏掉任何一个产生分析树的情况。

# %%
nltk.app.rdparser()

# %%
# NLTK 提供了一个递归下降分析器：
rd_parser = nltk.RecursiveDescentParser(grammar1)
sent = "Mary saw a dog".split()
for t in rd_parser.parse(sent):
    print(t)
# Out:
# (S (NP Mary) (VP (V saw) (NP (Det a) (N dog))))

# %% [markdown]
# 递归下降分析有三个主要的缺点。首先，左递归产生式，如：`NP -> NP PP`，会进入死循环。第二，分析器浪费了很多时间处理不符合输入句子的词和结构。第三，回溯过程中可能会丢弃分析过的成分，它们将需要在之后再次重建。例如：从`VP -> V NP`上回溯将放弃为`NP` 创建的子树。如果分析器之后处理 `VP -> V NP PP`，那么`NP` 子树必须重新创建。**递归下降分析是一种自上而下分析**。自上而下分析器在检查输入之前先使用文法预测输入将是什么！然而，由于输入对分析器一直是可用的，从一开始就考虑输入的句子会是更明智的做法。这种方法被称为**自下而上分析**，在下一节中我们将看到一个例子。
#
#
# #### 移进-归约分析
#
# **一种简单的自下而上分析器是移进-归约分析器**。与所有自下而上的分析器一样，移进-归约分析器尝试找到对应文法生产式右侧的词和短语的序列，用左侧的替换它们，直到整个句子归约为一个S。 移位-规约分析器反复将下一个输入词推到堆栈（见 4.1节），这是移位操作。如果堆栈上的前n 项，匹配一些产生式的右侧的n 个项目，那么就把它们弹出栈，并把产生式左边的项目压入栈。**这种替换前n 项为一项的操作就是规约操作**。**此操作只适用于堆栈的顶部**；规约栈中的项目必须在后面的项目被压入栈之前做。当所有的输入都使用过，堆栈中只剩余一个项目，也就是一颗分析树作为它的根的S节点时，分析器完成。移位-规约分析器通过上述过程建立一颗分析树。每次弹出堆栈 n 个项目，它就将它们组合成部分的分析树，然后将 这压回推栈。我们可以使用图形化示范 `nltk.app.srparser()`看到移位-规约分析算法步骤。 执行此分析器的六个阶段如图 8-7 所示。
# ![8-7](./imgs/8-7.jpg)

# %%
nltk.app.srparser()
# Out:
# Warning: VP -> V NP PP will never be used

# %% [markdown]
# NLTK中提供了`ShiftReduceParser()`，移进-归约分析器的一个简单的实现。这个分析器不执行任何回溯，所以它不能保证一定能找到一个文本的解析，即使确实存在一个这样的解析。此外，它最多只会找到一个解析，即使有多个解析存在。我们可以提供一个可选的 `trace` 参数，控制分析器报告它分析一个文本的步骤的繁琐程度。

# %%
sr_parser = nltk.ShiftReduceParser(grammar1, trace=2) #以跟踪模式运行上述分析器
sent = "Mary saw a dog".split()
# print(sr_parser.parse(sent))
for t in sr_parser.parse(sent):
    print(t)
# Out:
# Parsing 'Mary saw a dog'
#     [ * Mary saw a dog]
#   S [ 'Mary' * saw a dog]
#   R [ NP * saw a dog]
#   S [ NP 'saw' * a dog]
#   R [ NP V * a dog]
#   S [ NP V 'a' * dog]
#   R [ NP V Det * dog]
#   S [ NP V Det 'dog' * ]
#   R [ NP V Det N * ]
#   R [ NP V NP * ]
#   R [ NP VP * ]
#   R [ S * ]
# (S (NP Mary) (VP (V saw) (NP (Det a) (N dog))))

# %% [markdown]
# 移进-规约分析器可能会到达一个死胡同，而不能找到任何解析，即使输入的句子是符合语法的。这种情况发生时，没有剩余的输入，而堆栈包含不能被规约到一个 S的项目。 问题出现的原因是：较早前做出的选择不能被分析器撤销（虽然图形演示中用户可以撤消它 们的选择）。分析器可以做两种选择：（a）当有多种规约可能时选择哪个规约，（b）当移进和规约都可以时选择哪个动作。
#
# 移进-规约分析器可以改进执行策略来解决这些冲突。例如：它可以通过只有在不能规 约时才移进，解决移进-规约冲突；它可以通过优先执行规约操作，解决规约-规约冲突；它可以从堆栈移除更多的项目。（一个通用的移进-规约分析器，是一个“超前 LR 分析器”， 普遍使用在编程语言编译器中。）
#
# 移进-规约分析器相比递归下降分析器的好处是，它们只建立与输入中的词对应的结构。 此外，每个结构它们只建立一次。例如：NP(Det(the), N(man))只建立和压入栈一次， 不管以后VP -> V NP PP 规约或者 NP -> NP PP 规约会不会用到。
#
#
# #### 左角落分析器
#
# 递归下降分析器的问题之一是当它遇到一个左递归产生式时，会进入无限循环。这是因 为它盲目应用文法产生式而不考虑实际输入的句子。左角落分析器是我们已经看到的自下而 上与自上而下方法的混合体。
#
# **左角落分析器是一个带自下而上过滤的自上而下的分析器**。不像普通的递归下降分析器，它不会陷入左递归产生式的陷井。在开始工作之前，左角落分析器预处理上下文无关文法建立一个表，其中每行包含两个单元，第一个存放非终结符，第二个存放那个非终结符可能的左角落的集合。表 8-2 用 grammar2的文法演示了这一点。
# ![list8-2](./imgs/list8-2.jpg)
#
# 分析器每次考虑产生式时，它会检查下一个输入词是否与左角落表格中至少一种非终结符的类别相容。
#
# #### 符合语句规则的子串表
#
# 上面讨论的简单的分析器在完整性和效率上都有限制。为了弥补这些，我们将运用**动态规划**算法设计技术分析问题。正如我们在 4.7节中所看到的，动态规划存储中间结果，并在适当的时候重用它们，能显著提高效率。
#
# 这种技术可以应用到句法分析，使我们能够存储分析任务的部分解决方案，然后在必要的时候查找它们，直到达到最终解决方案。这种分析方法被称为**图表分析**。我们在本节中介绍它的主要思想；更多的实施细节请看网上提供的本章的材料。
#
# 动态规划使我们能够只建立一次 `PP in my pajamas`。第一次我们建立时就把它存入一个表格中，然后在我们需要作为对象 `NP`或更高的`VP`的组成部分用到它时我们就查找表格。这个表格被称为**符合语法规则的子串表**或简称为**WFST**。（术语“串”指一个句子中的连续的词序列。）我们将展示如何自下而上的构建WFST，以便系统地记录已经找到的句法成分。 让我们设置我们的输入为句子（2）。指定`WFST` 的跨度的数值让人联想起 Python的分片符号（3.2节）。这种数据结构的另一种方式如图 8-6 所示，一个称为图表的数据结构。
# ![8-6](./imgs/8-6.jpg)
#
# 在 `WFST` 中，我们通过填充三角矩阵中的单元记录词的位置：纵轴表示一个子串的起始位置，而横轴表示结束位置（从而 `shot` 将出现在坐标`(1, 2)`的单元中）。为了简化这个演示，我们将假定每个词有一个独特的词汇类别，我们将在矩阵中存储词汇类别（不是词）。 所以单元`(1, 2)`将包含条目`V`。更一般的，如果我们输入的字符串是 `a1a2 ... an`，我们的文法包含一个形为`A → ai`的产生式，那么我们把`A` 添加到单元`(i-1, i)`。 所以，对于 `text` 中的每个词，我们可以在我们的文法中查找它所属的类别。

# %%
text = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']

# %% [markdown]
# 对于我们的`WFST`，我们用 Python 中的**链表的链表**创建一个`(n-1)×(n-1)`的矩阵，在例8-3中的函数 `init_wfst()`中用每个标识符的词汇类型初始化它。我们还定义一个实用的函数 `display()`来为我们精美的输出`WFST`。正如预期的那样，`V`在`(1, 2)`单元中。

# %%
# 例8-3. 使用符合语句规则的子串表的接收器
def init_wfst(tokens, grammar):
    numtokens = len(tokens)
    wfst = [[None for i in range(numtokens + 1)] for j in range(numtokens + 1)]
    for i in range(numtokens):
        productions = grammar.productions(rhs=tokens[i])
        wfst[i][i + 1] = productions[0].lhs()
    return wfst

def complete_wfst(wfst, tokens, grammar, trace=False):
    index = dict((p.rhs(), p.lhs()) for p in grammar.productions())
    numtokens = len(tokens)
    for span in range(2, numtokens+1):
        for start in range(numtokens+1-span):
            end = start + span
            for mid in range(start+1, end):
                nt1, nt2 = wfst[start][mid], wfst[mid][end]
                if nt1 and nt2 and (nt1, nt2) in index:
                    wfst[start][end] = index[(nt1, nt2)]
                    if trace:
                        print ("[%s] %3s [%s] %3s [%s] ==> [%s] %3s [%s]" %
                        (start, nt1, mid, nt2, end, start, index[(nt1, nt2)], end))
    return wfst

def display(wfst, tokens):
    print('\nWFST ' + ' '.join([("%-4d" % i) for i in range(1, len(wfst))]))
    for i in range(len(wfst) - 1):
        print("%d   " % i, end="")
        for j in range(1, len(wfst)): 
            print("%-4s" % (wfst[i][j] or '.'), end="")
        print()

tokens = "I shot an elephant in my pajamas".split()
wfst0 = init_wfst(tokens, groucho_grammar)
display(wfst0, tokens)
# Out:
# WFST 1    2    3    4    5    6    7
# 0   NP  .   .   .   .   .   .
# 1   .   V   .   .   .   .   .
# 2   .   .   Det .   .   .   .
# 3   .   .   .   N   .   .   .
# 4   .   .   .   .   P   .   .
# 5   .   .   .   .   .   Det .
# 6   .   .   .   .   .   .   N

# %%
wfst1 = complete_wfst(wfst0, tokens, groucho_grammar)
display(wfst1, tokens)
# Out:
# WFST 1    2    3    4    5    6    7
# 0    NP  .   .   S   .   .   S
# 1    .   V   .   VP  .   .   VP
# 2    .   .   Det NP  .   .   .
# 3    .   .   .   N   .   .   .
# 4    .   .   .   .   P   .   PP
# 5    .   .   .   .   .   Det NP
# 6    .   .   .   .   .   .   N

# %% [markdown]
# 回到我们的表格表示，假设对于词 `an` 我们有 `Det` 在`(2, 3)`单元，对以词 `elephant` 有 `N`
# 在`(3, 4)`单元，对于`an elephant` 我们应该在`(2, 4)`放入什么？我们需要找到一个形如`NP → Det N`的产生式。查询了文法，我们知道我们可以输入`(0, 2)`单元的 `NP`。
#
# 更一般的，我们可以在`(i, j)`输入 `A`，如果有一个产生式`A → B C`，并且我们在`(i, k)` 中找到非终结符 `B`，在`(k, j)`中找到非终结符`C`。例 8-3中的程序使用此规则完成`WFST`。通过调用函数`complete_wfst()`时设置 `trace` 为 `True`，我们看到了显示`WFST` 正在被创建的跟踪输出

# %%
wfst1 = complete_wfst(wfst0, tokens, groucho_grammar, trace=True)
# Out:
# [2] Det [3]   N [4] ==> [2]  NP [4]
# [5] Det [6]   N [7] ==> [5]  NP [7]
# [1]   V [2]  NP [4] ==> [1]  VP [4]
# [4]   P [5]  NP [7] ==> [4]  PP [7]
# [0]  NP [1]  VP [4] ==> [0]   S [4]
# [1]  VP [4]  PP [7] ==> [1]  VP [7]
# [0]  NP [1]  VP [7] ==> [0]   S [7]

# %% [markdown]
# 我们得出结论：只要我们已经在(0, 7)单元构建了一个 `S` 节点，表明我们已经找到了一
# 个涵盖了整个输入的句子，我们就为整个输入字符串找到了一个解析。最后的WFST 状态 如图 8-7 所示。
# ![8-77](./imgs/8-77.jpg)
#
# 请注意，在这里我们没有使用任何内置的分析函数。我们已经从零开始实现了一个完整的**初级图表分析器**！
#
# `WFST` 有几个缺点。首先，正如你可以看到的，`WFST` 本身不是一个分析树，所以该技术严格地说是认识到一个句子被一个文法承认，而不是分析它。其次，它要求每个非词汇文法生产式是二元的。虽然可以将任意的 `CFG` 转换为这种形式，我们宁愿使用这种方法时没有这样的规定。第三，作为一个自下而上的方法，它潜在的存在浪费，它会在不符合文法的地方提出成分。 最后，WFST 并不能表示句子中的结构歧义（如两个动词短语的读取）。`(2, 8)`单元中的 `VP` 实际上被输入了两次，一次是读取`V NP`，一次是读取`VP PP`。这是不同的假设，第二个会覆盖第一个（虽然如此，这并不重要，因为左侧是相同的。）图表分析器使用稍微更丰富的数据结构和一些有趣的算法来解决这些问题（见 8.8节）。

# %%
nltk.app.chartparser()
# Out:
# grammar= (
# ('    ', 'S -> NP VP,')
# ('    ', 'VP -> VP PP,')
# ('    ', 'VP -> V NP,')
# ('    ', 'VP -> V,')
# ('    ', 'NP -> Det N,')
# ('    ', 'NP -> NP PP,')
# ('    ', 'PP -> P NP,')
# ('    ', "NP -> 'John',")
# ('    ', "NP -> 'I',")
# ('    ', "Det -> 'the',")
# ('    ', "Det -> 'my',")
# ('    ', "Det -> 'a',")
# ('    ', "N -> 'dog',")
# ('    ', "N -> 'cookie',")
# ('    ', "N -> 'table',")
# ('    ', "N -> 'cake',")
# ('    ', "N -> 'fork',")
# ('    ', "V -> 'ate',")
# ('    ', "V -> 'saw',")
# ('    ', "P -> 'on',")
# ('    ', "P -> 'under',")
# ('    ', "P -> 'with',")
# )
# tokens = ['John', 'ate', 'the', 'cake', 'on', 'the', 'table']
# Calling "ChartParserApp(grammar, tokens)"...

# %% [markdown]
# ### 8.5 依存关系和依存文法
#
# 短语结构文法是关于词和词序列如何结合起来形成句子成分的。一个独特的和互补的方式，**依存文法**，集中关注的是**词与其他词之间的关系**。依存关系是**一个中心词与它的依赖之间的二元对称关系**。一个句子的中心词通常是动词，所有其他词要么依赖于中心词，要么依赖路径与它联通。
#
# **依存关系表示是一个加标签的有向图**，其中**节点是词汇项**，**加标签的弧表示依赖关系**， 从中心词到依赖。图 8-8 显示了一个依存关系图，箭头从中心词指出它们的依赖。
# ![8-8](./imgs/8-8.jpg)
#
# 图 8-8 中的弧加了依赖与它的中心词之间的语法功能标签。例如：`I` 是 `shot`（这是整个
# 句子的中心词）的 `SBJ`（主语），`in` 是一个 `NMOD`（`elephant` 的名词修饰语）。与短语结构文 法相比，依存文法可以作为一种依存关系直接用来表示语法功能。
#
# 下面是 NLTK为依存文法编码的一种方式——注意它只能捕捉依存关系信息，不能指定依存关系类型：

# %%
# groucho_dep_grammar = nltk.parse_dependency_grammar("""
groucho_dep_grammar = nltk.grammar.DependencyGrammar.fromstring("""
'shot' -> 'I' | 'elephant' | 'in'
'elephant' -> 'an' | 'in' 
'in' -> 'pajamas' 
'pajamas' -> 'my'
""")
print(groucho_dep_grammar)
# Out:
# Dependency grammar with 7 productions
#   'shot' -> 'I'
#   'shot' -> 'elephant'
#   'shot' -> 'in'
#   'elephant' -> 'an'
#   'elephant' -> 'in'
#   'in' -> 'pajamas'
#   'pajamas' -> 'my'

# %% [markdown]
# 依存关系图是一个**投影**，当所有的词都按线性顺序书写，边可以在词上绘制而不会交叉。这等于是说一个词及其所有后代依赖（依赖及其依赖的依赖，等等）在句子中形成一个连续的词序列。图 8-8是一个投影，我们可以使用**投影依存关系分析器**分析很多英语句子。下面的例子演示 `groucho_dep_grammar` 如何提供了一种替代的方法来捕捉附着歧义，我们之前在研究短语结构语法中遇到的。

# %%
pdp = nltk.ProjectiveDependencyParser(groucho_dep_grammar)
sent = 'I shot an elephant in my pajamas'.split()
trees = pdp.parse(sent)
for tree in trees:
    print(tree)
# Out:
# (shot I (elephant an (in (pajamas my))))
# (shot I (elephant an) (in (pajamas my)))

# %% [markdown]
# #### 配价与词汇
#
# 在依存文法的传统中，在表 8-3 中的动词被认为具有不同的配价。配价限制不仅适用于动词，也适用于其他类的中心词。
#
# ![list8-3](./imgs/list8-3.jpg)
#
# 配价是一个词项的属性，我们将在第 9 章进一步讨论它。补语往往与修饰语对照，虽然两者都是依存关系的类别。
#
#
# ### 8.6 文法开发
#
# #### 树库和文法
# `corpus`模块定义了树库语料的阅读器，其中包含了宾州树库语料的 10％的样本。

# %%
from nltk.corpus import treebank
t = treebank.parsed_sents("wsj_0001.mrg")[0]
print(t)
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %% [markdown]
# 我们可以利用这些数据来帮助开发一个文法。例如：例 8-4中的程序使用一个简单的过滤器找出带句子补语的动词。假设我们已经有一个形如 `VP -> SV S` 的产生式，这个信息使我们能够识别那些包括在`SV` 的扩张中的特别的动词。

# %%
# 例8-4. 搜索树库找出句子的补语。
def filter(tree):
    child_nodes = [child.label() for child in tree if isinstance(child, nltk.Tree)]
    return (tree.label() == 'VP') and ('S' in child_nodes)

from nltk.corpus import treebank
[subtree for tree in treebank.parsed_sents()
    for subtree in tree.subtrees(filter)]
# Out:
# [Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nonexecutive']), Tree('NN', ['director'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['this']), Tree('JJ', ['British']), Tree('JJ', ['industrial']), Tree('NN', ['conglomerate'])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree(',', [',']), Tree('``', ['``']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['This'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('NP-PRD', [Tree('DT', ['an']), Tree('JJ', ['old']), Tree('NN', ['story'])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('-NONE-', ['*?*'])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBZ', ['appears']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['the']), Tree('JJS', ['highest'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('DT', ['any']), Tree('NN', ['asbestos']), Tree('NNS', ['workers'])]), Tree('RRC', [Tree('VP', [Tree('VBN', ['studied']), Tree('NP', [Tree('-NONE-', ['*'])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('JJ', ['Western']), Tree('VBN', ['industrialized']), Tree('NNS', ['countries'])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBP', ['have']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['recognize']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['these']), Tree('NNS', ['events'])]), Tree('VP', [Tree('VBD', ['took']), Tree('NP', [Tree('NN', ['place'])]), Tree('ADVP-TMP', [Tree('NP', [Tree('CD', ['35']), Tree('NNS', ['years'])]), Tree('IN', ['ago'])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['continued']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['slide'])])])]), Tree(',', [',']), Tree('PP-LOC', [Tree('IN', ['amid']), Tree('NP', [Tree('NNS', ['signs']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['portfolio']), Tree('NNS', ['managers'])]), Tree('VP', [Tree('VBP', ['expect']), Tree('NP', [Tree('NP', [Tree('JJ', ['further']), Tree('NNS', ['declines'])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['interest']), Tree('NNS', ['rates'])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['thought']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['indicate']), Tree('NP', [Tree('VBG', ['declining']), Tree('NN', ['interest']), Tree('NNS', ['rates'])]), Tree('SBAR-PRP', [Tree('IN', ['because']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['they'])]), Tree('VP', [Tree('VBP', ['permit']), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['portfolio']), Tree('NNS', ['managers'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['retain']), Tree('NP', [Tree('RB', ['relatively']), Tree('JJR', ['higher']), Tree('NNS', ['rates'])]), Tree('PP-TMP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['a']), Tree('JJR', ['longer']), Tree('NN', ['period'])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['permit']), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['portfolio']), Tree('NNS', ['managers'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['retain']), Tree('NP', [Tree('RB', ['relatively']), Tree('JJR', ['higher']), Tree('NNS', ['rates'])]), Tree('PP-TMP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['a']), Tree('JJR', ['longer']), Tree('NN', ['period'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['considered']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-9'])]), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['sign'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('VBG', ['rising']), Tree('NNS', ['rates'])])])])]), Tree('SBAR-PRP', [Tree('IN', ['because']), Tree('S', [Tree('NP-SBJ', [Tree('NN', ['portfolio']), Tree('NNS', ['managers'])]), Tree('VP', [Tree('MD', ['can']), Tree('VP', [Tree('VB', ['capture']), Tree('NP', [Tree('JJR', ['higher']), Tree('NNS', ['rates'])]), Tree('ADVP-TMP', [Tree('RB', ['sooner'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['considered']), Tree('PP', [Tree('IN', ['by']), Tree('NP-LGS', [Tree('DT', ['some'])])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('NP-PRD', [Tree('DT', ['a']), Tree('JJR', ['stronger']), Tree('NN', ['indicator'])]), Tree('SBAR-PRP', [Tree('IN', ['because']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['those']), Tree('NNS', ['managers'])]), Tree('VP', [Tree('VBP', ['watch']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['market'])]), Tree('ADVP-MNR', [Tree('RB', ['closely'])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBP', ['continue']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['pour']), Tree('NP', [Tree('NN', ['cash'])]), Tree('PP-DIR', [Tree('IN', ['into']), Tree('NP', [Tree('NN', ['money']), Tree('NNS', ['funds'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['elected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-10'])]), Tree('NP-PRD', [Tree('DT', ['a']), Tree('NN', ['director'])])])]),
#  Tree('VP', [Tree('VBZ', ['expects']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VP', [Tree('VB', ['obtain']), Tree('NP', [Tree('JJ', ['regulatory']), Tree('NN', ['approval'])])]), Tree('CC', ['and']), Tree('VP', [Tree('VB', ['complete']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['transaction'])])]), Tree('PP-TMP', [Tree('IN', ['by']), Tree('NP', [Tree('NN', ['year-end'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['voted']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['raise']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['ceiling'])]), Tree('PP-DIR', [Tree('TO', ['to']), Tree('NP', [Tree('QP', [Tree('$', ['$']), Tree('CD', ['3.1']), Tree('CD', ['trillion'])]), Tree('-NONE-', ['*U*'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['act']), Tree('PP-TMP', [Tree('IN', ['until']), Tree('NP', [Tree('JJ', ['next']), Tree('NN', ['week'])])]), Tree('PP-TMP', [Tree('IN', ['at']), Tree('NP', [Tree('DT', ['the']), Tree('JJS', ['earliest'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-12'])]), Tree('NP-PRD', [Tree('NP', [Tree('NP', [Tree('JJ', ['senior']), Tree('NN', ['vice']), Tree('NN', ['president'])]), Tree('PP', [Tree('-NONE-', ['*RNR*-1'])])]), Tree('CC', ['and']), Tree('NP', [Tree('NP', [Tree('JJ', ['general']), Tree('NN', ['manager'])]), Tree('PP', [Tree('-NONE-', ['*RNR*-1'])])]), Tree('PP-1', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['this']), Tree('NNP', ['U.S.']), Tree('NNS', ['sales']), Tree('CC', ['and']), Tree('NN', ['marketing']), Tree('NN', ['arm'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['Japanese']), Tree('NN', ['auto']), Tree('NN', ['maker']), Tree('NNP', ['Mazda']), Tree('NNP', ['Motor']), Tree('NNP', ['Corp'])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['decided']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['treat']), Tree('NP', [Tree('PRP$', ['its']), Tree('NNS', ['guests'])]), Tree('PP-MNR', [Tree('PP', [Tree('ADVP', [Tree('JJR', ['more'])]), Tree('IN', ['like']), Tree('NP', [Tree('NP', [Tree('NN', ['royalty'])]), Tree('CC', ['or']), Tree('NP', [Tree('NN', ['rock']), Tree('NNS', ['stars'])])])]), Tree('PP', [Tree('IN', ['than']), Tree('NP', [Tree('NN', ['factory']), Tree('NNS', ['owners'])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['tempts']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['them'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['return']), Tree('PP-DIR', [Tree('TO', ['to']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['heartland']), Tree('NN', ['city'])])]), Tree('PP-PRP', [Tree('IN', ['for']), Tree('NP', [Tree('JJ', ['future']), Tree('NNS', ['meetings'])])])])])])]),
#  Tree('VP', [Tree('VBG', ['trying']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['keep']), Tree('NP-CLR', [Tree('NN', ['pace'])]), Tree('PP-CLR', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('JJ', ['rival'])]), Tree('NP', [Tree('NNP', ['Time']), Tree('NN', ['magazine'])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('NP-PRD', [Tree('NNP', ['Newsweek']), Tree('NN', ['president'])])])]),
#  Tree('VP', [Tree('VBZ', ['has']), Tree('ADVP-TMP', [Tree('RB', ['yet'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['announce']), Tree('NP', [Tree('PRP$', ['its']), Tree('CD', ['1990']), Tree('NN', ['ad']), Tree('NNS', ['rates'])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBD', ['evaluated']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('VBG', ['raising']), Tree('NP', [Tree('PRP$', ['our']), Tree('NN', ['bid'])])])]), Tree('ADVP-TMP', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBD', ['added']), Tree('S', [Tree('-NONE-', ['*T*-2'])])]),
#  Tree('VP', [Tree('VBD', ['added']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBN', ['elected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-15'])]), Tree('NP-PRD', [Tree('NP', [Tree('NNS', ['directors'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['this']), Tree('NN', ['consumer']), Tree('NNS', ['electronics']), Tree('CC', ['and']), Tree('NNS', ['appliances']), Tree('NN', ['retailing']), Tree('NN', ['chain'])])])])])]),
#  Tree('VP', [Tree('VBN', ['ordered']), Tree('NP-2', [Tree('-NONE-', ['*-1'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['refund']), Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('$', ['$']), Tree('CD', ['250']), Tree('CD', ['million'])]), Tree('-NONE-', ['*U*'])]), Tree('PP-DIR-CLR', [Tree('TO', ['to']), Tree('NP', [Tree('PRP$', ['its']), Tree('JJ', ['current']), Tree('CC', ['and']), Tree('JJ', ['former']), Tree('NNS', ['ratepayers'])])]), Tree('PP-PRP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('JJ', ['illegal']), Tree('NNS', ['rates'])]), Tree('VP', [Tree('VBN', ['collected']), Tree('NP', [Tree('-NONE-', ['*'])]), Tree('PP-PRP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('NN', ['cost']), Tree('NNS', ['overruns'])]), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nuclear']), Tree('NN', ['power']), Tree('NN', ['plant'])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['ordered']), Tree('NP-1', [Tree('NNP', ['Edison'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['make']), Tree('NP', [Tree('NP', [Tree('JJ', ['average']), Tree('NNS', ['refunds'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('$', ['$']), Tree('CD', ['45']), Tree('TO', ['to']), Tree('$', ['$']), Tree('CD', ['50'])]), Tree('-NONE-', ['*U*'])]), Tree('ADVP', [Tree('DT', ['each'])])])])]), Tree('PP-DIR', [Tree('TO', ['to']), Tree('NP', [Tree('NP', [Tree('NNP', ['Edison']), Tree('NNS', ['customers'])]), Tree('SBAR', [Tree('WHNP-18', [Tree('WP', ['who'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-18'])]), Tree('VP', [Tree('VBP', ['have']), Tree('VP', [Tree('VBN', ['received']), Tree('NP', [Tree('JJ', ['electric']), Tree('NN', ['service'])]), Tree('PP-TMP', [Tree('IN', ['since']), Tree('NP', [Tree('NNP', ['April']), Tree('CD', ['1986'])])])])])])]), Tree(',', [',']), Tree('PP', [Tree('VBG', ['including']), Tree('NP', [Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('CD', ['two']), Tree('CD', ['million'])]), Tree('NNS', ['customers'])]), Tree('SBAR', [Tree('WHNP-19', [Tree('WP', ['who'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-19'])]), Tree('VP', [Tree('VBP', ['have']), Tree('VP', [Tree('VBN', ['moved']), Tree('PP-TMP', [Tree('IN', ['during']), Tree('NP', [Tree('DT', ['that']), Tree('NN', ['period'])])])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['ordered']), Tree('NP-1', [Tree('DT', ['the']), Tree('NNS', ['refunds'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['begin']), Tree('NP-TMP', [Tree('NNP', ['Feb.']), Tree('CD', ['1'])])])])])]),
#  Tree('VP', [Tree('VBN', ['held']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('NP-PRD', [Tree('NN', ['hostage'])])]), Tree('PP-TMP', [Tree('IN', ['through']), Tree('NP', [Tree('NP', [Tree('DT', ['another']), Tree('NN', ['round'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNS', ['appeals'])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-2'])])]),
#  Tree('VP', [Tree('VBG', ['considering']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VBG', ['appealing']), Tree('NP', [Tree('NP', [Tree('NNP', ['Judge']), Tree('NNP', ['Curry']), Tree('POS', ["'s"])]), Tree('NN', ['order'])])])])]),
#  Tree('VP', [Tree('VB', ['force']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['it'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['slash']), Tree('NP', [Tree('PRP$', ['its']), Tree('CD', ['1989']), Tree('NNS', ['earnings'])]), Tree('PP-EXT', [Tree('IN', ['by']), Tree('NP', [Tree('NP', [Tree('$', ['$']), Tree('CD', ['1.55']), Tree('-NONE-', ['*U*'])]), Tree('NP-ADV', [Tree('DT', ['a']), Tree('NN', ['share'])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['found']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['the']), Tree('NNS', ['rates'])]), Tree('ADJP-PRD', [Tree('JJ', ['illegal'])])])]),
#  Tree('VP', [Tree('VBD', ['ordered']), Tree('NP-1', [Tree('DT', ['the']), Tree('NN', ['commission'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VP', [Tree('VB', ['audit']), Tree('NP', [Tree('NP', [Tree('NNP', ['Commonwealth']), Tree('NNP', ['Edison']), Tree('POS', ["'s"])]), Tree('NN', ['construction']), Tree('NNS', ['expenses'])])]), Tree('CC', ['and']), Tree('VP', [Tree('VB', ['refund']), Tree('NP', [Tree('DT', ['any']), Tree('JJ', ['unreasonable']), Tree('NNS', ['expenses'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['rule']), Tree('PP-CLR', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Braidwood']), Tree('CD', ['2']), Tree('NN', ['case'])])]), Tree('PP-TMP', [Tree('IN', ['by']), Tree('NP', [Tree('NN', ['year']), Tree('NN', ['end'])])])])])])]),
#  Tree('VP', [Tree('VBD', ['had']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['refund']), Tree('NP', [Tree('QP', [Tree('$', ['$']), Tree('CD', ['72.7']), Tree('CD', ['million'])]), Tree('-NONE-', ['*U*'])]), Tree('PP-PRP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('JJ', ['poor']), Tree('NN', ['performance'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['its']), Tree('NNP', ['LaSalle']), Tree('NNP', ['I']), Tree('JJ', ['nuclear']), Tree('NN', ['plant'])])])])])])])])]),
#  Tree('VP', [Tree('VB', ['help']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('VB', ['meet']), Tree('NP', [Tree('NP', [Tree('ADJP', [Tree('VBG', ['increasing']), Tree('CC', ['and']), Tree('VBG', ['diversifying'])]), Tree('NN', ['demand'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NN', ['control']), Tree('NNS', ['products'])])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['South']), Tree('NNP', ['Korea'])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['appears']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['depend']), Tree('ADVP-MNR', [Tree('RB', ['heavily'])]), Tree('PP-CLR', [Tree('IN', ['on']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['creativity']), Tree('PRN', [Tree(':', ['--']), Tree('CC', ['and']), Tree('NN', ['longevity']), Tree(':', ['--'])])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('PRP$', ['its']), Tree('NX', [Tree('NX', [Tree('NN', ['chairman'])]), Tree('CC', ['and']), Tree('NX', [Tree('NN', ['chief']), Tree('NN', ['designer'])])])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Seymour']), Tree('NNP', ['Cray'])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['made']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-3'])]), Tree('ADJP-PRD', [Tree('JJ', ['public'])])]), Tree('PP-TMP', [Tree('IN', ['until']), Tree('NP', [Tree('NN', ['yesterday'])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('DT', ['an']), Tree('NN', ['interview'])])])]),
#  Tree('VP', [Tree('VB', ['want']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['fund']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['project'])]), Tree('SBAR', [Tree('WHNP-22', [Tree('WDT', ['that'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-22'])]), Tree('VP', [Tree('VBD', ['did']), Tree('RB', ['not']), Tree('VP', [Tree('VB', ['include']), Tree('NP', [Tree('NNP', ['Seymour'])])])])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['anticipates']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VBG', ['needing']), Tree('NP', [Tree('NP', [Tree('ADVP', [Tree('RB', ['perhaps'])]), Tree('DT', ['another']), Tree('QP', [Tree('$', ['$']), Tree('CD', ['120']), Tree('CD', ['million'])]), Tree('-NONE-', ['*U*'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['financing'])])])]), Tree('PP-TMP', [Tree('VBG', ['beginning']), Tree('NP', [Tree('JJ', ['next']), Tree('NNP', ['September'])])])])])]),
#  Tree('VP', [Tree('VBD', ['called']), Tree('S', [Tree('NP-SBJ', [Tree('IN', ['that'])]), Tree('NP-PRD', [Tree('``', ['``']), Tree('DT', ['a']), Tree('JJ', ['worst-case']), Tree("''", ["''"]), Tree('NN', ['scenario'])])])]),
#  Tree('VP', [Tree('VBD', ['caused']), Tree('S', [Tree('NP-SBJ-1', [Tree('NNP', ['Cray']), Tree('NNP', ['Research']), Tree('NN', ['stock'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['jump']), Tree('NP-EXT', [Tree('$', ['$']), Tree('CD', ['2.875']), Tree('-NONE-', ['*U*'])]), Tree('NP-TMP', [Tree('NN', ['yesterday'])]), Tree('S-CLR', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['close']), Tree('PP-LOC-CLR', [Tree('IN', ['at']), Tree('NP', [Tree('$', ['$']), Tree('CD', ['38']), Tree('-NONE-', ['*U*'])])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['New']), Tree('NNP', ['York']), Tree('NNP', ['Stock']), Tree('NNP', ['Exchange']), Tree('JJ', ['composite']), Tree('NN', ['trading'])])])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['has']), Tree('S', [Tree('NP-SBJ-21', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('VP', [Tree('VBN', ['considered']), Tree('NP', [Tree('-NONE-', ['*-21'])]), Tree('PP-CLR', [Tree('IN', ['as']), Tree('NP', [Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['additional']), Tree('NN', ['risk'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['investor'])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['roll']), Tree('PRT', [Tree('RP', ['out'])]), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['C-90']), Tree('NN', ['machine'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['direct']), Tree('NN', ['competitor'])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Cray-3'])])])]), Tree(',', [','])]), Tree('PP-TMP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1991'])])])])])])]),
#  Tree('VP', [Tree('VBP', ['are']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['receive']), Tree('NP', [Tree('CD', ['one']), Tree('NNP', ['Cray']), Tree('NNP', ['Computer']), Tree('NN', ['share'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('QP', [Tree('DT', ['every']), Tree('CD', ['two'])]), Tree('NNP', ['Cray']), Tree('NNP', ['Research']), Tree('NNS', ['shares'])]), Tree('SBAR', [Tree('WHNP-2', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['they'])]), Tree('VP', [Tree('VBP', ['own']), Tree('NP', [Tree('-NONE-', ['*T*-2'])])])])])])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['distribution'])]), Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['occur']), Tree('PP-TMP', [Tree('IN', ['in']), Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('CD', ['two'])]), Tree('NNS', ['weeks'])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['occur']), Tree('PP-TMP', [Tree('IN', ['in']), Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('CD', ['two'])]), Tree('NNS', ['weeks'])])])])])])]),
#  Tree('VP', [Tree('VB', ['leave']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['it'])]), Tree('PP-PRD', [Tree('IN', ['up']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['marketplace'])])])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['decide'])])])])])]),
#  Tree('VP', [Tree('VBN', ['applied']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['trade']), Tree('PP-LOC', [Tree('IN', ['on']), Tree('NP', [Tree('NNP', ['Nasdaq'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-27'])]), Tree('NP-PRD', [Tree('NP', [Tree('NP', [Tree('JJ', ['senior']), Tree('NN', ['executive']), Tree('NN', ['vice']), Tree('NN', ['president'])]), Tree('CC', ['and']), Tree('NP', [Tree('NN', ['chief']), Tree('VBG', ['operating']), Tree('NN', ['officer'])])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['both']), Tree('JJ', ['new']), Tree('NNS', ['positions'])])])])]),
#  Tree('VP', [Tree('VB', ['continue']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['report']), Tree('PP-CLR', [Tree('TO', ['to']), Tree('NP', [Tree('NP', [Tree('NNP', ['Donald']), Tree('NNP', ['Pardus'])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('NN', ['president'])]), Tree('CC', ['and']), Tree('NP', [Tree('NN', ['chief']), Tree('NN', ['executive']), Tree('NN', ['officer'])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-28'])]), Tree('NP-PRD', [Tree('NP', [Tree('NN', ['executive']), Tree('NN', ['vice']), Tree('NN', ['president'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['company'])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['succeed']), Tree('NP', [Tree('NNP', ['Mr.']), Tree('NNP', ['Hatch'])]), Tree('PP-CLR', [Tree('IN', ['as']), Tree('NP', [Tree('NP', [Tree('NN', ['president'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Eastern']), Tree('NNP', ['Edison'])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-29'])]), Tree('NP-PRD', [Tree('NP', [Tree('JJ', ['senior']), Tree('NN', ['vice']), Tree('NN', ['president'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Eastern']), Tree('NNPS', ['Utilities'])])])])])]),
#  Tree('VP', [Tree('ADVP', [Tree('RB', ['allegedly'])]), Tree('VBG', ['failing']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-3'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['honor']), Tree('NP', [Tree('NNP', ['U.S.']), Tree('NX', [Tree('NX', [Tree('NNS', ['patents'])]), Tree(',', [',']), Tree('NX', [Tree('NNS', ['copyrights'])]), Tree('CC', ['and']), Tree('NX', [Tree('JJ', ['other']), Tree('JJ', ['intellectual-property']), Tree('NNS', ['rights'])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['trained']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['pursue']), Tree('NP', [Tree('NN', ['movie']), Tree('CC', ['and']), Tree('NN', ['book']), Tree('NNS', ['pirates'])])])])])]),
#  Tree('VP', [Tree('VB', ['compel']), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NP', [Tree('NNP', ['Taipei']), Tree('POS', ["'s"])]), Tree('VBG', ['growing']), Tree('NN', ['number'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['small']), Tree('JJ', ['video-viewing']), Tree('NNS', ['parlors'])])])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['pay']), Tree('NP', [Tree('NN', ['movie']), Tree('NNS', ['producers'])]), Tree('PP-PRP', [Tree('IN', ['for']), Tree('S-NOM', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('VBG', ['showing']), Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['films'])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['vowed']), Tree('S', [Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['enact']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['copyright']), Tree('NN', ['law'])]), Tree('ADJP', [Tree('JJ', ['compatible']), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('JJ', ['international']), Tree('NNS', ['standards'])])])])])])])]), Tree('CC', ['and']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['apply']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['law'])]), Tree('PP-CLR', [Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NN', ['computer']), Tree('NN', ['software'])])]), Tree('CONJP', [Tree('RB', ['as']), Tree('RB', ['well']), Tree('IN', ['as'])]), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('JJ', ['literary']), Tree('NNS', ['works'])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['deemed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['pose']), Tree('NP', [Tree('NP', [Tree('JJ', ['less-serious']), Tree('NNS', ['problems'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('JJ', ['American']), Tree('NN', ['patent']), Tree('CC', ['and']), Tree('NN', ['copyright']), Tree('NNS', ['owners'])])]), Tree('PP', [Tree('IN', ['than']), Tree('NP', [Tree('NP', [Tree('DT', ['those'])]), Tree('PP-LOC', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['the']), Tree('``', ['``']), Tree('NN', ['priority']), Tree("''", ["''"]), Tree('NN', ['list'])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBZ', ['requires']), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['Mrs.']), Tree('NNP', ['Hills'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['issue']), Tree('NP', [Tree('NP', [Tree('DT', ['another']), Tree('NN', ['review'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['performance'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['these']), Tree('NNS', ['countries'])])])])])]), Tree('PP-TMP', [Tree('IN', ['by']), Tree('NP', [Tree('NNP', ['April']), Tree('CD', ['30'])])])])])])]),
#  Tree('VP', [Tree('VBD', ['deemed']), Tree('S', [Tree('NP-SBJ-1', [Tree('DT', ['any']), Tree('NNS', ['cases'])]), Tree('ADJP-PRD', [Tree('JJ', ['bad']), Tree('RB', ['enough']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['merit']), Tree('NP', [Tree('DT', ['an']), Tree('VBN', ['accelerated']), Tree('NN', ['investigation'])])])]), Tree('PP-LOC', [Tree('IN', ['under']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['so-called']), Tree('JJ', ['special']), Tree('CD', ['301']), Tree('NN', ['provision'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['act'])])])])])])])])]),
#  Tree('VP', [Tree('VB', ['ask']), Tree('NP-1', [Tree('NN', ['creditor']), Tree('NNS', ['banks'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['halve']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('PRP$', ['its']), Tree('JJ', ['foreign']), Tree('NN', ['debt'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('QP', [Tree('$', ['$']), Tree('CD', ['64']), Tree('CD', ['billion'])]), Tree('-NONE-', ['*U*'])])])]), Tree('PRN', [Tree(':', ['--']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('JJS', ['third-highest'])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('DT', ['the']), Tree('VBG', ['developing']), Tree('NN', ['world'])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['believed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['first']), Tree('NN', ['time'])]), Tree('SBAR-TMP', [Tree('WHADVP-2', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ-3', [Tree('JJ', ['such']), Tree('DT', ['an']), Tree('NN', ['action'])]), Tree('VP', [Tree('VBZ', ['has']), Tree('VP', [Tree('VBN', ['been']), Tree('VP', [Tree('VBN', ['called']), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('-NONE-', ['*-3'])])]), Tree('PP', [Tree('IN', ['by']), Tree('NP-LGS', [Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['Argentine']), Tree('NN', ['official'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['such']), Tree('NN', ['stature'])])])])]), Tree('ADVP-TMP', [Tree('-NONE-', ['*T*-2'])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['aspires']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['reach']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['reduction'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('CD', ['50']), Tree('NN', ['%'])])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['value'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['its']), Tree('JJ', ['external']), Tree('NN', ['debt'])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])]), Tree('PP-MNR', [Tree('IN', ['through']), Tree('NP', [Tree('NP', [Tree('PRP$', ['his']), Tree('NN', ['spokesman'])]), Tree(',', [',']), Tree('NP', [Tree('NNP', ['Miguel']), Tree('NNP', ['Alurralde'])])])])]),
#  Tree('VP', [Tree('VBZ', ['wants']), Tree('S', [Tree('NP-SBJ-2', [Tree('PDT', ['half']), Tree('DT', ['the']), Tree('NN', ['debt'])]), Tree('VP', [Tree('VBN', ['forgiven']), Tree('NP', [Tree('-NONE-', ['*-2'])])])])]),
#  Tree('VP', [Tree('VBD', ['had']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['use']), Tree('NP', [Tree('PRP$', ['their']), Tree('NN', ['television']), Tree('NNS', ['sets'])]), Tree('PP-CLR', [Tree('IN', ['as']), Tree('NP', [Tree('NNS', ['screens'])])])])])])]),
#  Tree('VP', [Tree('VBP', ['allow']), Tree('S', [Tree('NP-SBJ', [Tree('NNS', ['PCs'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['share']), Tree('NP', [Tree('NNS', ['data'])]), Tree('PP-MNR', [Tree('IN', ['via']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['telephone'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['scheduled']), Tree('S', [Tree('NP-SBJ-35', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('VP', [Tree('VBN', ['brought']), Tree('NP', [Tree('-NONE-', ['*-35'])]), Tree('PP-CLR', [Tree('IN', ['into']), Tree('NP', [Tree('NN', ['production'])])]), Tree('PP-TMP', [Tree('IN', ['before']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['end'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('CD', ['1990'])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ-1', [Tree('-NONE-', ['*-3'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['start']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VBG', ['producing']), Tree('NP-TMP-2', [Tree('JJ', ['early']), Tree('JJ', ['next']), Tree('NN', ['year'])])])])])])])]),
#  Tree('VP', [Tree('VB', ['start']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VBG', ['producing']), Tree('NP-TMP-2', [Tree('JJ', ['early']), Tree('JJ', ['next']), Tree('NN', ['year'])])])])]),
#  Tree('VP', [Tree('VBD', ['decided']), Tree('PP-TMP', [Tree('IN', ['in']), Tree('NP', [Tree('CD', ['1987'])])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['make']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['first']), Tree('QP', [Tree('CD', ['30']), Tree('CD', ['million'])]), Tree('NNS', ['barrels'])]), Tree('PP-MNR', [Tree('IN', ['from']), Tree('NP', [Tree('NP', [Tree('JJ', ['new']), Tree('NNS', ['fields'])]), Tree('ADJP', [Tree('JJ', ['free']), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['excise']), Tree('NN', ['tax'])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['decided']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['divest']), Tree('NP', [Tree('PRP', ['itself'])]), Tree('PP-CLR', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('JJ', ['certain'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('PRP$', ['its']), Tree('JJ', ['non-encapsulating']), Tree('NNS', ['businesses'])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['decided']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['grant']), Tree('NP', [Tree('NP', [Tree('JJ', ['duty-free']), Tree('NN', ['status'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('CD', ['18']), Tree('NNS', ['categories'])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['left']), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['Magna'])]), Tree('PP-PRD', [Tree('IN', ['with']), Tree('NP', [Tree('NP', [Tree('JJ', ['excess']), Tree('NN', ['capacity'])]), Tree('CC', ['and']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['heavy']), Tree('NN', ['debt']), Tree('NN', ['load'])])])])]), Tree('SBAR-TMP', [Tree('IN', ['as']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['the']), Tree('JJ', ['automotive']), Tree('NN', ['industry'])]), Tree('VP', [Tree('VBZ', ['enters']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['downturn'])])])])])]),
#  Tree('VP', [Tree('VBZ', ['wants']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['resume']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('ADJP', [Tree('RBR', ['more']), Tree('JJ', ['influential'])]), Tree('NN', ['role'])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('S-NOM', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('VBG', ['running']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['company'])])])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['expect']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['him'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['cut']), Tree('NP', [Tree('NNS', ['costs'])]), Tree('PP-LOC', [Tree('IN', ['throughout']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['organization'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-39'])]), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nonexecutive']), Tree('NN', ['director'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['this']), Tree('JJ', ['British']), Tree('NN', ['chemical']), Tree('NN', ['company'])])])])])]),
#  Tree('VP', [Tree('VBZ', ['forces']), Tree('S', [Tree('NP-SBJ', [Tree('NNS', ['investors'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['redeploy']), Tree('NP', [Tree('PRP$', ['their']), Tree('NN', ['money'])]), Tree('PP-CLR', [Tree('IN', ['at']), Tree('NP', [Tree('JJR', ['lower']), Tree('NNS', ['rates'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['named']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-44'])]), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['director'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['this']), Tree('NN', ['oil']), Tree('NN', ['concern'])])])])]), Tree(',', [',']), Tree('S-ADV', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('VBG', ['expanding']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['board'])]), Tree('PP-CLR', [Tree('TO', ['to']), Tree('NP', [Tree('CD', ['14']), Tree('NNS', ['members'])])])])])]),
#  Tree('VP', [Tree('VBD', ['agreed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['extend']), Tree('PP-TMP', [Tree('IN', ['until']), Tree('NP', [Tree('NP', [Tree('NNP', ['March']), Tree('CD', ['8'])]), Tree(',', [',']), Tree('NP', [Tree('CD', ['1990'])])])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['period'])]), Tree('SBAR', [Tree('WHPP-2', [Tree('IN', ['in']), Tree('WHNP', [Tree('WDT', ['which'])])]), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['the']), Tree('NN', ['steel']), Tree(',', [',']), Tree('NN', ['aerospace']), Tree('CC', ['and']), Tree('NN', ['energy']), Tree('NNS', ['products']), Tree('NN', ['company'])]), Tree('VP', [Tree('VBZ', ['has']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['exclusive']), Tree('NN', ['right']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['file']), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['reorganization']), Tree('NN', ['plan'])])])])])]), Tree('PP-TMP', [Tree('-NONE-', ['*T*-2'])])])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['attempts']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['work']), Tree('PRT', [Tree('RP', ['out'])]), Tree('NP', [Tree('DT', ['a']), Tree('NN', ['plan']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['pay']), Tree('NP', [Tree('PRP$', ['its']), Tree('NNS', ['debts'])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['scheduled']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['expire']), Tree('PP-TMP', [Tree('IN', ['at']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['end'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['November'])])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['quips']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBG', ['looking']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['stake']), Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['claims'])])])])]), Tree("''", ["''"]), Tree('ADVP-TMP', [Tree('RB', ['now'])]), Tree('SBAR-TMP', [Tree('RB', ['before']), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['number'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['available']), Tree('NNS', ['nations'])])])]), Tree('VP', [Tree('VBZ', ['runs']), Tree('PRT', [Tree('RP', ['out'])])])])])]),
#  Tree('VP', [Tree('VBZ', ['says']), Tree('S', [Tree('-NONE-', ['*T*-2'])])]),
#  Tree('VP', [Tree('VBN', ['scrambled']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['find']), Tree('NP', [Tree('NP', [Tree('JJ', ['new']), Tree('NNS', ['products'])]), Tree('SBAR', [Tree('WHNP-40', [Tree('WDT', ['that'])]), Tree('S', [Tree('NP-SBJ', [Tree('NNS', ['brokers'])]), Tree('VP', [Tree('VBP', ['find']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-40'])]), Tree('ADJP-PRD', [Tree('JJ', ['easy']), Tree('SBAR', [Tree('WHNP-2', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['sell']), Tree('NP', [Tree('-NONE-', ['*T*-2'])])])])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['find']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-40'])]), Tree('ADJP-PRD', [Tree('JJ', ['easy']), Tree('SBAR', [Tree('WHNP-2', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['sell']), Tree('NP', [Tree('-NONE-', ['*T*-2'])])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['urge']), Tree('NP-1', [Tree('NNS', ['investors'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['diversify'])])]), Tree('CC', ['and']), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['hold']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['smattering'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['international']), Tree('NNS', ['securities'])])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['tend']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['swing']), Tree('ADVP', [Tree('ADVP', [Tree('RBR', ['more'])]), Tree('PP', [Tree('IN', ['than']), Tree('NP', [Tree('DT', ['the']), Tree('JJR', ['broader']), Tree('NN', ['market'])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['says']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBZ', ['says']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBZ', ['says']), Tree(':', [':']), Tree('``', ['``']), Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('DT', ['The']), Tree('JJ', ['only']), Tree('NN', ['advice'])]), Tree('SBAR', [Tree('WHNP-2', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['I'])]), Tree('VP', [Tree('VBP', ['have']), Tree('NP', [Tree('-NONE-', ['*T*-2'])])])])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['these']), Tree('NNS', ['folks'])])])]), Tree('VP', [Tree('VBZ', ['is']), Tree('SBAR-PRD', [Tree('IN', ['that']), Tree('S', [Tree('NP-SBJ-4', [Tree('NP', [Tree('DT', ['those'])]), Tree('SBAR', [Tree('WHNP-3', [Tree('WP', ['who'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-3'])]), Tree('VP', [Tree('VBP', ['come']), Tree('PP-DIR', [Tree('TO', ['to']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['party'])])]), Tree('ADVP-TMP', [Tree('RB', ['late'])])])])])]), Tree('VP', [Tree('VBD', ['had']), Tree('PRT', [Tree('RBR', ['better'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-4'])]), Tree('VP', [Tree('VB', ['be']), Tree('ADJP-PRD', [Tree('JJ', ['ready']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-4'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['leave']), Tree('ADVP-MNR', [Tree('RB', ['quickly'])])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['had']), Tree('PRT', [Tree('RBR', ['better'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-4'])]), Tree('VP', [Tree('VB', ['be']), Tree('ADJP-PRD', [Tree('JJ', ['ready']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-4'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['leave']), Tree('ADVP-MNR', [Tree('RB', ['quickly'])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['permitted']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['a']), Tree('JJ', ['Soviet']), Tree('NN', ['bank'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['open']), Tree('NP', [Tree('DT', ['a']), Tree('NNP', ['New']), Tree('NNP', ['York']), Tree('NN', ['branch'])])])])])]),
#  Tree('VP', [Tree('VBD', ['failed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['rise']), Tree('PP-TMP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['September'])])])])])])]),
#  Tree('VP', [Tree('VBG', ['beginning']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['taper']), Tree('PRT', [Tree('RP', ['off'])])])])])]),
#  Tree('VP', [Tree('VBN', ['failed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['revive']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['residential']), Tree('NN', ['construction']), Tree('NN', ['industry'])])])])])]),
#  Tree('VP', [Tree('IN', ['about']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['slip']), Tree('PP-DIR', [Tree('IN', ['into']), Tree('NP', [Tree('NN', ['recession'])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBN', ['intended']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['last']), Tree('NP', [Tree('QP', [Tree('JJR', ['fewer']), Tree('IN', ['than']), Tree('CD', ['three'])]), Tree('NNS', ['years'])])])])])]),
#  Tree('VP', [Tree('VBZ', ['continues']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['indicate']), Tree('NP', [Tree('DT', ['a']), Tree('VBG', ['slowing']), Tree('NN', ['economy'])])])])])]),
#  Tree('VP', [Tree('VB', ['have']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('PP-PRD-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('DT', ['the']), Tree('ADJP', [Tree('JJ', ['low']), Tree('CD', ['40']), Tree('NN', ['%'])]), Tree('NN', ['range'])])]), Tree('PP-TMP', [Tree('IN', ['for']), Tree('NP', [Tree('JJ', ['several']), Tree('NNS', ['months'])])]), Tree('S-PRP', [Tree('NP-SBJ-55', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('VP', [Tree('VBN', ['considered']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-55'])]), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['forecast'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['recession'])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['considered']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-55'])]), Tree('NP-PRD', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['forecast'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['recession'])])])])])]),
#  Tree('VP', [Tree('VBP', ['consider']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['that'])]), Tree('NP-PRD', [Tree('DT', ['a']), Tree('NN', ['sign']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP-SBJ', [Tree('JJ', ['inflationary']), Tree('NNS', ['pressures'])]), Tree('VP', [Tree('VBP', ['are']), Tree('VP', [Tree('VBG', ['abating'])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['tend']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['rise'])])])])]),
# ...
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-2'])])]),
#  Tree('VP', [Tree('VBZ', ['has']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['weigh']), Tree(',', [',']), Tree('PP', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['the']), Tree('JJ', ['other']), Tree('NN', ['hand'])])]), Tree(',', [',']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('ADJP', [Tree('RB', ['relatively']), Tree('JJ', ['high'])]), Tree('NN', ['price'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['sugar'])])]), Tree('SBAR', [Tree('WHNP-3', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['it'])]), Tree('VP', [Tree('MD', ['can']), Tree('VP', [Tree('VB', ['earn']), Tree('NP', [Tree('-NONE-', ['*T*-3'])]), Tree('PP-LOC', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['export']), Tree('NN', ['market'])])])])])])])]), Tree('PP', [Tree('IN', ['in']), Tree('S-NOM', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('VBG', ['making']), Tree('NP', [Tree('NP', [Tree('NNS', ['decisions'])]), Tree('PP', [Tree('IN', ['as']), Tree('TO', ['to']), Tree('SBAR', [Tree('IN', ['whether']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['produce']), Tree('NP', [Tree('NN', ['sugar']), Tree('CC', ['or']), Tree('NN', ['alcohol'])])])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-2'])])]),
#  Tree('VP', [Tree('VBD', ['had']), Tree('S', [Tree('NP-SBJ-2', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['buy']), Tree('NP', [Tree('NN', ['sugar'])]), Tree('PP-LOC', [Tree('IN', ['on']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['world']), Tree('NN', ['market'])])]), Tree('S-PRP', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['meet']), Tree('NP', [Tree('NN', ['export']), Tree('NNS', ['commitments'])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('NP-PRD', [Tree('DT', ['a']), Tree('JJ', ['net']), Tree('NN', ['importer'])])])])])]),
#  Tree('VP', [Tree('VBN', ['said']), Tree('S', [Tree('NP-SBJ-2', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('VP', [Tree('VBG', ['seeking']), Tree('S', [Tree('NP-SBJ-3', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['buy']), Tree('NP', [Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('CD', ['200,000'])]), Tree('NNS', ['tons'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['sugar'])])])]), Tree('S-PRP', [Tree('NP-SBJ', [Tree('-NONE-', ['*-3'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['meet']), Tree('NP', [Tree('JJ', ['internal']), Tree('NNS', ['needs'])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBG', ['seeking']), Tree('S', [Tree('NP-SBJ-3', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['buy']), Tree('NP', [Tree('NP', [Tree('QP', [Tree('IN', ['about']), Tree('CD', ['200,000'])]), Tree('NNS', ['tons'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['sugar'])])])]), Tree('S-PRP', [Tree('NP-SBJ', [Tree('-NONE-', ['*-3'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['meet']), Tree('NP', [Tree('JJ', ['internal']), Tree('NNS', ['needs'])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['helped']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VB', ['push']), Tree('PRT', [Tree('RP', ['up'])]), Tree('NP', [Tree('JJ', ['crude']), Tree('NN', ['oil'])])])])]),
#  Tree('VP', [Tree('VBD', ['continued']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['withhold']), Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['crops'])]), Tree('PP-CLR', [Tree('IN', ['from']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['marketplace'])])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['hope'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('JJR', ['higher']), Tree('NNS', ['prices'])]), Tree('SBAR', [Tree('WHNP-2', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['come'])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['believed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['need']), Tree('NP', [Tree('JJ', ['additional']), Tree('NNS', ['supplies'])])])])]), Tree(',', [',']), Tree('PP', [Tree('IN', ['despite']), Tree('S-NOM', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('VBG', ['running']), Tree('PRT', [Tree('RP', ['up'])]), Tree('NP', [Tree('NP', [Tree('JJ', ['record']), Tree('JJ', ['one-month']), Tree('NNS', ['purchases'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('QP', [Tree('CD', ['310']), Tree('CD', ['million'])]), Tree('NNS', ['bushels'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['corn'])])])])])]), Tree('PP-TMP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['October'])])])])])])]),
#  Tree('VP', [Tree('VBD', ['urged']), Tree('NP-1', [Tree('PRP$', ['its']), Tree('NNP', ['Parliament'])]), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['extend']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['state'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['emergency'])])])]), Tree('PP-LOC', [Tree('IN', ['in']), Tree('NP', [Tree('JJ', ['copper-rich']), Tree('NNP', ['Bougainville']), Tree('NNP', ['Island'])])]), Tree('PP-TMP', [Tree('IN', ['for']), Tree('NP', [Tree('CD', ['two']), Tree('NNS', ['months'])])])])])])]),
#  Tree('VP', [Tree('VBP', ['want']), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['Bougainville'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['secede']), Tree('PP-CLR', [Tree('IN', ['from']), Tree('NP', [Tree('NNP', ['Papua-New']), Tree('NNP', ['Guinea'])])])])])])]),
#  Tree('VP', [Tree('VBG', ['failing']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['find']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['buyer'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['chain'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('JJ', ['Midwestern']), Tree('NN', ['department']), Tree('NNS', ['stores'])])])])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['considers']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-2'])]), Tree('NP-PRD', [Tree('``', ['``']), Tree('JJ', ['fair']), Tree('NN', ['value']), Tree("''", ["''"])])])]),
#  Tree('VP', [Tree('VBZ', ['hopes']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('ADVP', [Tree('RB', ['eventually'])]), Tree('VP', [Tree('VB', ['reduce']), Tree('NP', [Tree('NP', [Tree('PRP$', ['its']), Tree('NN', ['stake'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NNP', ['Younkers'])])])]), Tree('PP-CLR', [Tree('TO', ['to']), Tree('NP', [Tree('QP', [Tree('JJR', ['less']), Tree('IN', ['than']), Tree('CD', ['50'])]), Tree('NN', ['%'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['proposed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VBG', ['changing']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['offer'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['company'])])])]), Tree('PP-CLR', [Tree('TO', ['to']), Tree('NP', [Tree('NP', [Tree('$', ['$']), Tree('CD', ['13.65']), Tree('-NONE-', ['*U*'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['cash']), Tree('CC', ['and']), Tree('NN', ['stock'])])])])]), Tree('PP-CLR', [Tree('IN', ['from']), Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['all-cash']), Tree('NN', ['transaction'])])])])])]),
#  Tree('VP', [Tree('VBD', ['termed']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*T*-2'])]), Tree('NP-PRD', [Tree('DT', ['an']), Tree('``', ['``']), Tree('JJ', ['amicable']), Tree('NN', ['separation'])])])]),
#  Tree('VP', [Tree('VBD', ['declined']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['specify']), Tree('NP', [Tree('-NONE-', ['*T*-1'])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-2'])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree(',', [',']), Tree('``', ['``']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['I'])]), Tree('VP', [Tree('VBP', ['suspect']), Tree('SBAR', [Tree('-NONE-', ['0']), Tree('S', [Tree('-LRB-', ['-LRB-']), Tree('NP-SBJ', [Tree('DT', ['the']), Tree('NN', ['departure'])]), Tree('-RRB-', ['-RRB-']), Tree('VP', [Tree('MD', ['will']), Tree('VP', [Tree('VB', ['be']), Tree('ADJP-PRD', [Tree('RB', ['fairly']), Tree('JJ', ['irrelevant'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['company'])])])])])])])])])]),
#  Tree('VP', [Tree('VB', ['allow']), Tree('S', [Tree('NP-SBJ-2', [Tree('DT', ['this']), Tree('NN', ['process'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['be']), Tree('VP', [Tree('VBN', ['completed']), Tree('NP', [Tree('-NONE-', ['*-2'])])])])])])]),
#  Tree('VP', [Tree('VBZ', ['expects']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['report']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['third-quarter']), Tree('JJ', ['net']), Tree('NN', ['loss'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('QP', [Tree('$', ['$']), Tree('CD', ['17']), Tree('CD', ['million']), Tree('TO', ['to']), Tree('$', ['$']), Tree('CD', ['19']), Tree('CD', ['million'])]), Tree('-NONE-', ['*U*'])])])]), Tree('PP-PRP', [Tree('IN', ['because']), Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('JJ', ['special']), Tree('NNS', ['reserves'])]), Tree('CC', ['and']), Tree('NP', [Tree('VBN', ['continued']), Tree('JJ', ['low']), Tree('NN', ['natural-gas']), Tree('NNS', ['prices'])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['scheduled']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['arrive']), Tree('NP-TMP', [Tree('NN', ['tomorrow'])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBZ', ['is']), Tree('ADVP-PRD', [Tree('RB', ['still'])]), Tree(':', [':']), Tree('``', ['`']), Tree('S', [Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['We'])]), Tree('VP', [Tree('VBP', ['want']), Tree('S', [Tree('-LRB-', ['-LRB-']), Tree('NP-SBJ', [Tree('NNS', ['stocks'])]), Tree('-RRB-', ['-RRB-']), Tree('ADVP-PRD', [Tree('RB', ['up'])])])])]), Tree(',', [',']), Tree('CC', ['but']), Tree('S', [Tree('SBAR-ADV', [Tree('IN', ['if']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['they'])]), Tree('VP', [Tree('VBP', ['do']), Tree('RB', ["n't"]), Tree('VP', [Tree('VB', ['carry'])])])])]), Tree('NP-SBJ-1', [Tree('PRP', ['we'])]), Tree('VP', [Tree('VBP', ["'re"]), Tree('VP', [Tree('VBG', ['going']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['sell']), Tree('NP', [Tree('PRP', ['them'])])])])])])])])])]),
#  Tree('VP', [Tree('VBP', ['want']), Tree('S', [Tree('-LRB-', ['-LRB-']), Tree('NP-SBJ', [Tree('NNS', ['stocks'])]), Tree('-RRB-', ['-RRB-']), Tree('ADVP-PRD', [Tree('RB', ['up'])])])]),
#  Tree('VP', [Tree('VBG', ['going']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['sell']), Tree('NP', [Tree('PRP', ['them'])])])])])]),
#  Tree('VP', [Tree('VBD', ['helped']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-3'])]), Tree('VP', [Tree('VB', ['offset']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['impact'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NN', ['profit-taking'])])]), Tree('PP', [Tree('IN', ['among']), Tree('NP', [Tree('JJ', ['blue']), Tree('NNS', ['chips'])])])])])])]),
#  Tree('VP', [Tree('VBN', ['expected']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['remain']), Tree('ADJP-PRD', [Tree('VBN', ['subdued'])]), Tree('SBAR-TMP', [Tree('IN', ['as']), Tree('S', [Tree('NP-SBJ', [Tree('DT', ['the']), Tree('NN', ['market'])]), Tree('VP', [Tree('VBZ', ['awaits']), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NN', ['tomorrow']), Tree('POS', ["'s"])]), Tree('NN', ['release'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['the']), Tree('NNS', ['jobs']), Tree('NNS', ['data'])])])]), Tree('PP', [Tree('IN', ['with']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['hope']), Tree('SBAR', [Tree('IN', ['that']), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['it'])]), Tree('VP', [Tree('MD', ['will']), Tree('VP', [Tree('VB', ['point']), Tree('PP-DIR', [Tree('IN', ['toward']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['decline'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['interest']), Tree('NNS', ['rates'])])])])])])])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['said']), Tree('S', [Tree('-NONE-', ['*T*-1'])])]),
#  Tree('VP', [Tree('VBD', ['offered']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-2'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['acquire']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['stock'])]), Tree('SBAR', [Tree('WHNP-1', [Tree('-NONE-', ['0'])]), Tree('S', [Tree('NP-SBJ', [Tree('PRP', ['it'])]), Tree('VP', [Tree('VBZ', ['does']), Tree('RB', ["n't"]), Tree('ADVP', [Tree('RB', ['already'])]), Tree('VP', [Tree('VB', ['own']), Tree('NP', [Tree('-NONE-', ['*T*-1'])])])])])])]), Tree('PP-CLR', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('$', ['$']), Tree('CD', ['50']), Tree('-NONE-', ['*U*'])]), Tree('NP-ADV', [Tree('DT', ['a']), Tree('NN', ['share'])])])])])])])]),
#  Tree('VP', [Tree('VBN', ['caused']), Tree('S', [Tree('NP-SBJ-1', [Tree('NNS', ['analysts'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['consider']), Tree('SBAR', [Tree('IN', ['whether']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['cut']), Tree('NP', [Tree('NP', [Tree('PRP$', ['their']), Tree('NNS', ['estimates'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('NNP', ['Santa']), Tree('NNP', ['Fe']), Tree('POS', ["'s"])]), Tree('NN', ['asset']), Tree('NN', ['value'])])])])])])])])])])])]),
#  Tree('VP', [Tree('VBD', ['allowed']), Tree('S', [Tree('NP-SBJ-1', [Tree('DT', ['the']), Tree('NN', ['company'])]), Tree('VP', [Tree('TO', ['to']), Tree('VP', [Tree('VB', ['begin']), Tree('S', [Tree('NP-SBJ', [Tree('-NONE-', ['*-1'])]), Tree('VP', [Tree('VBG', ['marketing']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['new']), Tree('NN', ['lens'])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('NN', ['use'])]), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NN', ['cataract']), Tree('NNS', ['patients'])])])])])])])])])])])]),
#  ...]

# %% [markdown]
# `PP`附着语料库，`nltk.corpus.ppattach`，是另一个有关特别动词配价的信息源。在这里，我们演示挖掘这个语料库的技术。它找出具有固定的介词和名词的介词短语对，其中介词短语附着到`VP` 还是`NP`，由选择的动词决定。

# %%
entries = nltk.corpus.ppattach.attachments('training')
table = nltk.defaultdict(lambda: nltk.defaultdict(set))
for entry in entries:
    key = entry.noun1 + '-' + entry.prep + '-' + entry.noun2
    table[key][entry.attachment].add(entry.verb)

# %%
for key in sorted(table):
    if len(table[key]) > 1:
        print(key, 'N:', sorted(table[key]['N']), 'V:', sorted(table[key]['V']))
# Out:
# %-below-level N: ['left'] V: ['be']
# %-from-year N: ['was'] V: ['declined', 'dropped', 'fell', 'grew', 'increased', 'plunged', 'rose', 'was']
# %-in-August N: ['was'] V: ['climbed', 'fell', 'leaping', 'rising', 'rose']
# %-in-September N: ['increased'] V: ['climbed', 'declined', 'dropped', 'edged', 'fell', 'grew', 'plunged', 'rose', 'slipped']
# %-in-week N: ['declined'] V: ['was']
# %-to-% N: ['add', 'added', 'backed', 'be', 'cut', 'go', 'grow', 'increased', 'increasing', 'is', 'offer', 'plummet', 'reduce', 'rejected', 'rise', 'risen', 'shaved', 'wants', 'yield', 'zapping'] V: ['fell', 'rise', 'slipped']
# %-to-million N: ['declining'] V: ['advanced', 'climbed', 'cutting', 'declined', 'declining', 'dived', 'dropped', 'edged', 'fell', 'gained', 'grew', 'increased', 'jump', 'jumped', 'plunged', 'rising', 'rose', 'slid', 'slipped', 'soared', 'tumbled']
# 1-to-21 N: ['dropped'] V: ['dropped']
# 1-to-33 N: ['gained'] V: ['dropped', 'fell', 'jumped']
# 1-to-4 N: ['added'] V: ['gained']
# 1-to-47 N: ['jumped'] V: ['added', 'rose']
# 1-to-point N: ['ended'] V: ['fell', 'rose']
# 3-to-17 N: ['lost'] V: ['lost']
# 500,000-in-fines N: ['paid'] V: ['paid']
# 6.9-on-scale N: ['registered'] V: ['registered']
# access-to-AZT N: ['had'] V: ['had']
# access-to-arena N: ['permits'] V: ['lack']
# activity-in-part N: ['showed'] V: ['attributed']
# agreement-in-principle N: ['reached'] V: ['reached']
# agreement-with-Inc. N: ['announced', 'signed'] V: ['signed']
# agreement-with-creditors N: ['reached'] V: ['nearing']
# agreement-with-regulators N: ['presages', 'reach'] V: ['reach']
# aid-to-Contras N: ['renewing'] V: ['renewing']
# alliance-with-GM N: ['discussing', 'wrapping'] V: ['forge', 'have', 'negotiating']
# approval-for-drug N: ['granted'] V: ['obtain']
# attention-to-comments N: ['paid'] V: ['paid']
# attention-to-concerns N: ['pay'] V: ['show']
# attention-to-reports N: ['paid'] V: ['pay']
# bid-for-company N: ['fend', 'launch'] V: ['made', 'make']
# bid-for-million N: ['finance'] V: ['had']
# bids-for-company N: ['submitted'] V: ['solicit']
# billion-in-cash N: ['pay', 'raise'] V: ['raise']
# billion-of-bills N: ['sell', 'sold'] V: ['sold']
# billion-over-years N: ['total'] V: ['spent']
# billion-to-billion N: ['cause', 'place'] V: ['increased', 'rose']
# business-to-firms N: ['cutting'] V: ['give', 'transfer']
# business-with-them N: ['cease'] V: ['do']
# cap-on-amount N: ['eliminate'] V: ['places']
# cents-to-cents N: ['be', 'recovering'] V: ['fell', 'rose']
# change-in-earnings N: ['had'] V: ['had']
# changes-for-% N: ['measures'] V: ['measures', 'monitors']
# charge-in-quarter N: ['took'] V: ['had', 'included', 'incur', 'take', 'took']
# collar-on-trading N: ['re-establishing'] V: ['reinstating']
# commitments-from-banks N: ['secured', 'won'] V: ['obtained']
# competition-from-competitors N: ['faced'] V: ['fend']
# competition-in-production N: ['reduce'] V: ['reduce']
# contract-for-parts N: ['awarded', 'given', 'won'] V: ['received']
# contract-for-support N: ['awarded', 'issued'] V: ['received']
# contract-from-Co. N: ['received'] V: ['won']
# contract-with-Warner N: ['violates'] V: ['terminate']
# control-of-Inc. N: ['took'] V: ['seek']
# decline-for-quarter N: ['posted'] V: ['reported']
# decline-in-August N: ['followed', 'following', 'recorded'] V: ['following']
# decline-in-earnings N: ['alleviate', 'report', 'reported'] V: ['expects']
# declines-in-prices N: ['reflect'] V: ['had']
# disputes-with-company N: ['resolve'] V: ['resolve']
# domestic-production-through-July N: ['includes'] V: ['includes']
# drop-in-earnings N: ['posted'] V: ['posted']
# drop-in-profit N: ['experienced', 'had', 'posted', 'reported', 'reporting'] V: ['posted']
# earnings-for-companies N: ['reported'] V: ['reported']
# earnings-for-quarter N: ['posting'] V: ['posted', 'report', 'reported']
# earnings-in-quarter N: ['projecting'] V: ['had']
# earnings-of-million N: ['had', 'include', 'posted', 'reported'] V: ['reported']
# effect-on-market N: ['had'] V: ['had']
# emphasis-on-quality N: ['be'] V: ['place']
# financing-for-buy-out N: ['deliver', 'get'] V: ['obtaining']
# floor-for-price N: ['establishes'] V: ['providing']
# foot-in-door N: ['wanted'] V: ['getting']
# funding-for-abortion N: ['supporting'] V: ['oppose']
# funds-for-station N: ['including', 'providing'] V: ['includes']
# gain-from-sale N: ['included', 'includes'] V: ['a-Includes', 'including', 'record', 'report']
# gain-in-profit N: ['posted', 'reported'] V: ['posted']
# head-to-head N: ['going'] V: ['go']
# impact-on-market N: ['have'] V: ['has', 'have']
# impact-on-markets N: ['had'] V: ['have']
# impact-on-results N: ['have'] V: ['have']
# income-for-quarter N: ['announcing'] V: ['report']
# increase-in-earnings N: ['reported'] V: ['posted']
# information-from-companies N: ['requested'] V: ['steal']
# inquiry-into-activities N: ['conducted'] V: ['drop']
# interest-in-company N: ['bought', 'have', 'holds', 'owning', 'retain'] V: ['represent']
# interest-in-metals N: ['create'] V: ['was']
# interest-on-loans N: ['computing'] V: ['pay']
# loans-to-China N: ['suspended'] V: ['resuming']
# loss-for-quarter N: ['announced', 'have', 'post', 'posted', 'reported', 'reporting'] V: ['post', 'report', 'reported']
# loss-in-quarter N: ['expect', 'had'] V: ['caused', 'had', 'posted', 'took']
# losses-in-years N: ['reported'] V: ['had']
# markets-in-stocks N: ['making'] V: ['make']
# million-before-tax N: ['reported'] V: ['contributed']
# million-for-initiative N: ['attached'] V: ['add']
# million-for-stake N: ['pay'] V: ['paid', 'pay', 'putting']
# million-from-funds N: ['commit'] V: ['raises']
# million-from-operations N: ['included'] V: ['reported']
# million-from-sale N: ['including'] V: ['take']
# million-in-payments N: ['make', 'owes', 'pay', 'receive'] V: ['fallen']
# million-of-debt N: ['add', 'borrow', 'consolidate', 'convert', 'downgraded', 'includes', 'pay', 'raise'] V: ['assume']
# million-on-revenue N: ['earned'] V: ['earned', 'was', 'were']
# million-on-sales N: ['earned'] V: ['earned', 'reach', 'totaled', 'was', 'were']
# million-to-million N: ['be', 'bills', 'cost', 'pump', 'sell', 'totaled'] V: ['declined', 'fell', 'spend', 'tumbled']
# month-in-time N: ['delivered'] V: ['delivered']
# net-on-revenue N: ['posted'] V: ['reported']
# nothing-about-it N: ['knew'] V: ['doing']
# offer-for-all N: ['begun', 'make'] V: ['begin']
# offer-for-shares N: ['began', 'extended'] V: ['launched', 'made']
# offer-for-stock N: ['extended'] V: ['make']
# offer-from-group N: ['rejected'] V: ['received']
# office-in-Worth N: ['Call'] V: ['has']
# pace-with-inflation N: ['keep', 'keeping'] V: ['keep']
# payment-on-million N: ['make'] V: ['make']
# payments-on-debt N: ['cover', 'make'] V: ['make']
# president-in-charge N: ['is', 'named'] V: ['been']
# pressure-on-government N: ['keep'] V: ['keep', 'put']
# pressure-on-prices N: ['suffered'] V: ['keep', 'put']
# price-for-incentives N: ['paid'] V: ['paid']
# prices-on-market N: ['push'] V: ['bring']
# profit-for-year N: ['report'] V: ['report']
# profit-from-discontinued N: ['had'] V: ['was']
# profit-in-quarter N: ['indicates'] V: ['produce', 'recorded']
# projections-for-year N: ['slashed'] V: ['exceed']
# provisions-for-loans N: ['taken'] V: ['made']
# rates-to-% N: ['boosting'] V: ['increase', 'pushed', 'raised']
# reporter-in-bureau N: ['is'] V: ['is']
# restrictions-on-use N: ['waiving'] V: ['impose']
# revenue-for-year N: ['projected'] V: ['had']
# revenue-in-quarter N: ['expects'] V: ['had']
# sales-in-excess N: ['combined'] V: ['had']
# sales-in-quarter N: ['had'] V: ['increasing']
# sales-of-million N: ['expected', 'had', 'has', 'have', 'posted'] V: ['had']
# salvo-in-battle N: ['marking'] V: ['marking']
# services-for-customers N: ['offering'] V: ['provide']
# shareholder-in-bank N: ['become'] V: ['become']
# stake-in-Airlines N: ['acquiring', 'buy', 'raise'] V: ['buy']
# stake-in-Mixte N: ['bring'] V: ['boost']
# stake-in-Rally N: ['hold'] V: ['had']
# stake-in-company N: ['bought', 'building', 'built', 'buying', 'give', 'hold', 'obtaining', 'own', 'owns', 'raised', 'take'] V: ['accumulating', 'had', 'has', 'holds', 'own']
# stake-in-concern N: ['acquires', 'lowered'] V: ['retaining']
# stake-in-unit N: ['sell'] V: ['acquire']
# stake-in-venture N: ['has', 'hold', 'holds'] V: ['held']
# suit-against-Keating N: ['press'] V: ['brought']
# swings-in-market N: ['cause', 'create'] V: ['cause']
# system-for-city N: ['design'] V: ['design']
# system-in-Pakistan N: ['operate'] V: ['operate']
# time-for-Congress N: ['is'] V: ['buy', 'buys']
# venture-with-Co. N: ['started'] V: ['started']
# ventures-with-companies N: ['established'] V: ['form']
# verdict-in-case N: ['is', 'won'] V: ['won']
# volatility-in-stocks N: ['ignoring'] V: ['see']
# vote-on-issue N: ['allow'] V: ['prevent']
# way-for-declines N: ['open'] V: ['pave']
# writer-in-York N: ['is'] V: ['is']
# yen-to-yen N: ['shed'] V: ['advanced', 'fell', 'gained', 'lost', 'rose']

# %% [markdown]
# NLTK 语料库也收集了中央研究院树库语料，包括10000 句已分析的句子，来自现代汉语中央研究院平衡语料库。让我们加载并显示这个语料库中的一棵树。

# %%
nltk.corpus.sinica_treebank.parsed_sents()[3450].draw()

# %% [markdown]
# #### 有害的歧义
# #### 加权文法
#
# ### 8.7 小结
#
# - 句子都有内部组织结构，可以用一棵树表示。组成结构的显著特点是：递归、中心词、补语和修饰语。
# - 文法是一个潜在的无限的句子集合的一个紧凑的特性；我们说，一棵树是符合语法规则的或文法树授权一棵树。
# - 文法是用于描述一个给定的短语是否可以被分配一个特定的成分或依赖结构的一种形式化模型。
# - 给定一组句法类别，上下文无关文法使用一组生产式表示某类型`A` 的短语如何能够被分析成较小的序列`α1 ... αn`。
# - 依存文法使用产生式指定给定的中心词的依赖是什么。
# - 当一个句子有一个以上的文法分析就产生句法歧义（如介词短语附着歧义）
# - 分析器是一个过程，为符合语法规则的句子寻找一个或多个相应的树。
# - 一个简单的自上而下分析器是递归下降分析器，在文法产生式的帮助下递归扩展开始符号（通常是`S`），尝试匹配输入的句子。这个分析器并不能处理左递归产生式（如：`NP -> NP PP`）。它盲目扩充类别而不检查它们是否与输入字符串兼容的方式效率低下，而且会重复扩充同样的非终结符然后丢弃结果。
# - 一个简单的自下而上的分析器是移位-规约分析器，它把输入移到一个堆栈中，并尝试匹配堆栈顶部的项目和文法产生式右边的部分。这个分析器不能保证为输入找到一个有 效的解析，即使它确实存在，它建立子结构而不检查它是否与全部文法一致。
